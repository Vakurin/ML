# %% [markdown]
# # Multiple Linear Regression
# ---

# %%
from IPython.display import Image
Image("img/Formula.png", width=650, height=450)

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Importing the dataset
dataset = pd.read_csv('Data/50_Startups.csv')
X = dataset.iloc[:, :-1].values #Independent
y = dataset.iloc[:, 4].values #Dependent

# %%
Image("img/Dummy Var.png", width=650, height=450)

# %%
dataset.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
# Encoding categorical data
# Encoding the Independent Variable
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder_X = LabelEncoder()
X[:, 3] = labelencoder_X.fit_transform(X[:, 3])
onehotencoder = OneHotEncoder(categorical_features = [3])
X = onehotencoder.fit_transform(X).toarray()

# %%
#Avoiding the Dummy Variables Trap 
X = X[:, 1:]

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size = 0.2, 
                                                    random_state = 0)

# %%
#Fitting Multiple Linear Regression Module to the train set
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
#Prediction Test Set Results
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([103015.20159796, 132582.27760815, 132447.73845175,  71976.09851258,
#        178537.48221056, 116161.24230166,  67851.69209676,  98791.73374687,
#        113969.43533013, 167921.06569551])

# %%
Image("img/5 method bulid a model.png", width=650, height=450)

# %% [markdown]
# # Bulding the optimal model using Backward Elimination
#
# ### If P-Value > SL(Significance level = 0.06(6%)) remove this column
# ### When all P-Values < SL model is ready

# %%
Image("img/Backward Elimination.png", width=650, height=450)

# %%
import statsmodels.formula.api as sm
X = np.append(arr=np.ones((50, 1)).astype(int), values = X, axis = 1)

# %%
X_opt = X[:, [0, 1, 2, 3, 4, 5]]
regressor_OLS = sm.OLS(endog=y, exog=X_opt).fit()
regressor_OLS.summary(title='P Value')
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                    P Value
# ...
# Dep. Variable:                      y   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     169.9
# Date:                Thu, 23 Aug 2018   Prob (F-statistic):           1.34e-27
# Time:                        21:20:30   Log-Likelihood:                -525.38
# No. Observations:                  50   AIC:                             1063.
# Df Residuals:                      44   BIC:                             1074.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.013e+04   6884.820      7.281      0.000    3.62e+04     6.4e+04
# ...

# %%
X_opt = X[:, [0, 1, 3, 4, 5]]
regressor_OLS = sm.OLS(endog=y, exog=X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.946
# Method:                 Least Squares   F-statistic:                     217.2
# Date:                Thu, 23 Aug 2018   Prob (F-statistic):           8.49e-29
# Time:                        21:20:55   Log-Likelihood:                -525.38
# No. Observations:                  50   AIC:                             1061.
# Df Residuals:                      45   BIC:                             1070.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.011e+04   6647.870      7.537      0.000    3.67e+04    6.35e+04
# ...

# %%
X_opt = X[:, [0, 3, 4, 5]]
regressor_OLS = sm.OLS(endog=y, exog=X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     296.0
# Date:                Thu, 23 Aug 2018   Prob (F-statistic):           4.53e-30
# Time:                        21:21:05   Log-Likelihood:                -525.39
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      46   BIC:                             1066.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.012e+04   6572.353      7.626      0.000    3.69e+04    6.34e+04
# ...

# %%
X_opt = X[:, [0, 3, 5]]
regressor_OLS = sm.OLS(endog=y, exog=X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.950
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     450.8
# Date:                Thu, 23 Aug 2018   Prob (F-statistic):           2.16e-31
# Time:                        21:21:13   Log-Likelihood:                -525.54
# No. Observations:                  50   AIC:                             1057.
# Df Residuals:                      47   BIC:                             1063.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.698e+04   2689.933     17.464      0.000    4.16e+04    5.24e+04
# ...

# %%
#Backward Elimination with p-values only:
import statsmodels.formula.api as sm
def backwardElimination(x, sl):
    numVars = len(x[0])
    for i in range(0, numVars):
        regressor_OLS = sm.OLS(y, x).fit()
        maxVar = max(regressor_OLS.pvalues).astype(float)
        if maxVar > sl:
            for j in range(0, numVars - i):
                if (regressor_OLS.pvalues[j].astype(float) == maxVar):
                    x = np.delete(x, j, 1)
    regressor_OLS.summary()
    return x
 
SL = 0.07
X_opt = X[:, [0, 1, 2, 3, 4, 5]]
X_Modeled = backwardElimination(X_opt, SL)
list(X_Modeled)
# Out:
# [array([1.000000e+00, 1.653492e+05, 4.717841e+05]),
#  array([1.0000000e+00, 1.6259770e+05, 4.4389853e+05]),
#  array([1.0000000e+00, 1.5344151e+05, 4.0793454e+05]),
#  array([1.0000000e+00, 1.4437241e+05, 3.8319962e+05]),
#  array([1.0000000e+00, 1.4210734e+05, 3.6616842e+05]),
#  array([1.0000000e+00, 1.3187690e+05, 3.6286136e+05]),
#  array([1.0000000e+00, 1.3461546e+05, 1.2771682e+05]),
#  array([1.0000000e+00, 1.3029813e+05, 3.2387668e+05]),
#  array([1.0000000e+00, 1.2054252e+05, 3.1161329e+05]),
#  array([1.0000000e+00, 1.2333488e+05, 3.0498162e+05]),
#  array([1.0000000e+00, 1.0191308e+05, 2.2916095e+05]),
#  array([1.0000000e+00, 1.0067196e+05, 2.4974455e+05]),
#  array([1.0000000e+00, 9.3863750e+04, 2.4983944e+05]),
#  array([1.0000000e+00, 9.1992390e+04, 2.5266493e+05]),
#  array([1.0000000e+00, 1.1994324e+05, 2.5651292e+05]),
#  array([1.0000000e+00, 1.1452361e+05, 2.6177623e+05]),
#  array([1.0000000e+00, 7.8013110e+04, 2.6434606e+05]),
# ...

# %%
#Backward Elimination with p-values and Adjusted R Squared:

import statsmodels.formula.api as sm
def backwardElimination(x, SL):
    numVars = len(x[0])
    temp = np.zeros((50,6)).astype(int)
    for i in range(0, numVars):
        regressor_OLS = sm.OLS(y, x).fit()
        maxVar = max(regressor_OLS.pvalues).astype(float)
        adjR_before = regressor_OLS.rsquared_adj.astype(float)
        if maxVar > SL:
            for j in range(0, numVars - i):
                if (regressor_OLS.pvalues[j].astype(float) == maxVar):
                    temp[:,j] = x[:, j]
                    x = np.delete(x, j, 1)
                    tmp_regressor = sm.OLS(y, x).fit()
                    adjR_after = tmp_regressor.rsquared_adj.astype(float)
                    if (adjR_before >= adjR_after):
                        x_rollback = np.hstack((x, temp[:,[0,j]]))
                        x_rollback = np.delete(x_rollback, j, 1)
                        print (regressor_OLS.summary())
                        return x_rollback
                    else:
                        continue
    regressor_OLS.summary()
    return x
 
SL = 0.05
X_opt = X[:, [0, 1, 2, 3, 4, 5]]
X_Modeled = backwardElimination(X_opt, SL)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.950
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     450.8
# Date:                Thu, 23 Aug 2018   Prob (F-statistic):           2.16e-31
# Time:                        21:25:48   Log-Likelihood:                -525.54
# No. Observations:                  50   AIC:                             1057.
# Df Residuals:                      47   BIC:                             1063.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.698e+04   2689.933     17.464      0.000    4.16e+04    5.24e+04
# ...

# %%
Image("img/Bidirectional Elimination.png", width=650, height=450)

# %%
Image("img/Forward Selection.png", width=650, height=450)

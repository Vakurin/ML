# %%
from stocker import Stocker

# %%
fb = Stocker('FB')
# Out:
# FB Stocker Initialized. Data covers 2012-05-18 to 2018-03-27.
# /Users/vakurin/Desktop/ML/Data Analysis/Stock Price Analysis With Stocker/stocker.py:70: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   self.starting_price = float(self.stock.ix[0, 'Adj. Open'])
# /Users/vakurin/Desktop/ML/Data Analysis/Stock Price Analysis With Stocker/stocker.py:73: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   self.most_recent_price = float(self.stock.ix[len(self.stock) - 1, 'y'])

# %%
fb_history = fb.stock
fb_history.head()
# Out:
#         Date   Open   High    Low    Close       Volume  Ex-Dividend  \
# 0 2012-05-18  42.05  45.00  38.00  38.2318  573576400.0          0.0
# 1 2012-05-21  36.53  36.66  33.00  34.0300  168192700.0          0.0
# 2 2012-05-22  32.61  33.59  30.94  31.0000  101786600.0          0.0
# 3 2012-05-23  31.37  32.50  31.36  32.0000   73600000.0          0.0
# 4 2012-05-24  32.95  33.21  31.77  33.0300   50237200.0          0.0
#
#    Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume  \
# 0          1.0      42.05      45.00     38.00     38.2318  573576400.0
# 1          1.0      36.53      36.66     33.00     34.0300  168192700.0
# 2          1.0      32.61      33.59     30.94     31.0000  101786600.0
# 3          1.0      31.37      32.50     31.36     32.0000   73600000.0
# 4          1.0      32.95      33.21     31.77     33.0300   50237200.0
#
#           ds        y  Daily Change
# 0 2012-05-18  38.2318       -3.8182
# 1 2012-05-21  34.0300       -2.5000
# ...

# %%
fb.buy_and_hold(start_date = '2012-09-04', end_date = '2018-02-01', nshares = 200)
# Out:
# FB Total buy and hold profit from 2012-09-04 to 2018-02-01 for 200 shares = $35002.00
# /Users/vakurin/Desktop/ML/Data Analysis/Stock Price Analysis With Stocker/stocker.py:178: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   trim_df = df[(df['Date'] >= start_date.date()) &
# /Users/vakurin/Desktop/ML/Data Analysis/Stock Price Analysis With Stocker/stocker.py:179: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   (df['Date'] <= end_date.date())]

# %%
model, model_data = fb.create_prophet_model()
# Out:
# /Users/vakurin/Desktop/ML/Data Analysis/Stock Price Analysis With Stocker/stocker.py:444: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   stock_history = self.stock[self.stock['Date'] > (self.max_date - pd.DateOffset(years = self.training_years)).date()]
